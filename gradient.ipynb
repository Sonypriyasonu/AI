# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonypriyasonu/AI/blob/master/gradient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
def gradient_decent(x,y):
  m_curr=1
  b_curr=0
  n=len(x)
  iterations=1000
  learing_rate=0.1
  for i in range(iterations):
    y_pred=m_curr*x+b_curr
    cost=sum([val**2 for val in (y-y_pred)])
    md=-np.sum(x*(y-y_pred))
    bd=-np.sum(y-y_pred)
    m_curr=m_curr-learing_rate*md
    b_curr=b_curr-learing_rate*bd
    print("m = {},c = {},iterations = {},cost {}".format(m_curr,b_curr,i,cost))
x=np.array([0.5,2.3,2.9])
y=np.array([1.4,1.9,3.2])
gradient_decent(x,y)
# Out:
# m = 1.04,c = 0.08000000000000003,iterations = 0,cost 1.0599999999999998
# m = 0.9786,c = 0.11320000000000002,iterations = 1,cost 0.9779999999999999
# m = 0.983929,c = 0.17143800000000003,iterations = 2,cost 0.9132149899999996
# m = 0.948628385,c = 0.20916707,iterations = 3,cost 0.8589228751367496
# m = 0.9410665580250002,c = 0.2556987695500001,iterations = 4,cost 0.8120013647894984
# m = 0.9175304109366249,c = 0.29258120061075,iterations = 5,cost 0.770835777160057
# m = 0.9058042033319057,c = 0.33181450619364883,iterations = 6,cost 0.73446304339869
# m = 0.8880730711535175,c = 0.36596175843636797,iterations = 7,cost 0.7022191960907349
# m = 0.875612934585631,c = 0.39997158034795266,iterations = 8,cost 0.6735921742902732
# m = 0.8611490900403428,c = 0.4308807335297572,iterations = 9,cost 0.6481585816579719
# m = 0.8492440913221031,c = 0.46076153214783466,iterations = 10,cost 0.6255549738389741
# m = 0.8369145106035037,c = 0.48846394044988556,iterations = 11,cost 0.6054635253700134
# ...
